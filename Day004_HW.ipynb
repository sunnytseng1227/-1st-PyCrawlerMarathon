# %%
# 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容：
# https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests 
r = requests.get('https://api.github.com/events')
r.text
# Out:
# "https://api.github.com/users/bobsilverberg/received_events","type":"User","site_admin":false},"assignees":[{"login":"bobsilverberg","id":142755,"node_id":"MDQ6VXNlcjE0Mjc1NQ==","avatar_url":"https://avatars1.githubusercontent.com/u/142755?v=4","gravatar_id":"","url":"https://api.github.com/users/bobsilverberg","html_url":"https://github.com/bobsilverberg","followers_url":"https://api.github.com/users/bobsilverberg/followers","following_url":"https://api.github.com/users/bobsilverberg/following{/other_user}","gists_url":"https://api.github.com/users/bobsilverberg/gists{/gist_id}","starred_url":"https://api.github.com/users/bobsilverberg/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/bobsilverberg/subscriptions","organizations_url":"https://api.github.com/users/bobsilverberg/orgs","repos_url":"https://api.github.com/users/bobsilverberg/repos","events_url":"https://api.github.com/users/bobsilverberg/events{/privacy}","received_events_url":"https://api.github.com/users/bobsilverberg/received_events","type":"User","site_admin":false}],"milestone":{"url":"https://api.github.com/repos/mozilla/addons-code-manager/milestones/47","html_url":"https://github.com/mozilla/addons-code-manager/milestone/47","labels_url":"https://api.github.com/repos/mozilla/addons-code-manager/milestones/47/labels","id":4866914,"node_id":"MDk6TWlsZXN0b25lNDg2NjkxNA==","number":47,"title":"2019.12.05","description":"","creator":{"login":"diox","id":187006,"node_id":"MDQ6VXNlcjE4NzAwNg==","avatar_url":"https://avatars0.githubusercontent.com/u/187006?v=4","gravatar_id":"","url":"https://api.github.com/users/diox","html_url":"https://github.com/diox","followers_url":"https://api.github.com/users/diox/followers","following_url":"https://api.github.com/users/diox/following{/other_user}","gists_url":"https://api.github.com/users/diox/gists{/gist_id}","starred_url":"https://api.github.com/users/diox/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/diox/subscriptions","organizations_url":"https://api.github.com/users/diox/orgs","repos_url":"https://api.github.com/users/diox/repos","events_url":"https://api.github.com/users/diox/events{/privacy}","received_events_url":"https://api.github.com/users/diox/received_events","type":"User","site_admin":false},"open_issues":2,"closed_issues":9,"state":"open","created_at":"2019-11-21T14:35:19Z","updated_at":"2019-11-28T14:47:09Z","due_on":"2019-12-03T08:00:00Z","closed_at":null},"comments":4,"created_at":"2019-08-06T21:39:38Z","updated_at":"2019-11-28T14:47:08Z","closed_at":"2019-11-28T14:47:08Z","author_association":"MEMBER","body":"User story:\\r\\n\\r\\n> As a code reviewer, I want to be able to enter custom comments for specific code lines in the file and diff viewer.\\r\\n\\r\\nWhen viewing a diff, the reviewer can enter a comment a specific line. This will be similar to adding a comment to a file (https://github.com/mozilla/addons-code-manager/issues/112).\\r\\n\\r\\nThe suggested UI flow per [meeting notes](https://docs.google.com/document/d/1y4crrHxhGejb3eZ6HpjtBdDqONJakfwtfjaOqwq-qZo/edit) is roughly this:\\r\\n- click on a line of a diff to begin entering a comment\\r\\n- when presented with a list of canned responses, click *other*\\r\\n- begin entering text\\r\\n- press save\\r\\n\\r\\nIt\'s possible that it will be easy to hook into `DiffView`. I originally thought it would be tricky and filed https://github.com/otakustay/react-diff-view/issues/59 which led to https://github.com/otakustay/react-diff-view/#customize-gutter . That approach may not be necessary anymore, though."}},"public":true,"created_at":"2019-11-28T14:47:10Z","org":{"id":131524,"login":"mozilla","gravatar_id":"","url":"https://api.github.com/orgs/mozilla","avatar_url":"https://avatars.githubusercontent.com/u/131524?"}},{"id":"10969879412","type":"PushEvent","actor":{"id":39413174,"login":"Kenney-G","display_login":"Kenney-G","gravatar_id":"","url":"https://api.github.com/users/Kenney-G","avatar_ ...

# %%
import json

r = requests.get('https://api.github.com/events')
json.loads(r.text)
# Out:
# onardo7422',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53455348?'},
#   'repo': {'id': 218889889,
#    'name': 'leonardo7422/Projeto_Integrador',
#    'url': 'https://api.github.com/repos/leonardo7422/Projeto_Integrador'},
#   'payload': {'push_id': 4332478997,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4147e7fc37a34d0d2fc51daf4e5c136214bb31ae',
#    'before': '10206f2ccd400d8ac01d6d37fa0ff66755f98edc',
#    'commits': [{'sha': '4147e7fc37a34d0d2fc51daf4e5c136214bb31ae',
#      'author': {'email': '53455348+leonardo7422@users.noreply.github.com',
#       'name': 'Leonardo Santana'},
#      'message': 'Delete conexao_rating.php',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/leonardo7422/Projeto_Integrador/commits/4147e7fc37a34d0d2fc51daf4e5c136214bb31ae'}]},
#   'public': True,
#   'created_at': '2019-11-28T14:47:10Z'},
#  {'id': '10969879518',
#   'type': 'PushEvent',
#   'actor': {'id': 58300745,
#    'login': 'saf-19',
#    'display_login': 'saf-19',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saf-19',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58300745?'},
#   'repo': {'id': 224667927,
#    'name': 'saf-19/CTEC2904',
#    'url': 'https://api.github.com/repos/saf-19/CTEC2904'},
#   'payload': {'push_id': 4332478986,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1ce6a82a545ddecb5efee52303b87aec46da1b1a',
#    'before': '368c16c549375e50d8cfefeba4796f3eb02e9a9d',
#    'commits': [{'sha': '1ce6a82a545ddecb5efee52303b87aec46da1b1a',
#      'author': {'email': '58300745+saf-19@users.noreply.github.com',
#       'name': 'saf-19'},
#      'message': 'create helloworld.c',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/saf-19/CTEC2904/commits/1ce6a82a545ddecb5efee52303b87aec46da1b1a'}]},
#   'public': True,
#   'created_at': '2019-11-28T14:47:10Z'},
#  {'id': '10969879504',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 35781410,
#    'login': 'Akhmetbekali',
#    'display_login': 'Akhmetbekali',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Akhmetbekali',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35781410?'},
#   'repo': {'id': 218290340,
#    'name': 'artyom-yurin/CC-Project',
#    'url': 'https://api.github.com/repos/artyom-yurin/CC-Project'},
#   'payload': {'action': 'opened',
#    'number': 6,
#    'pull_request': {'url': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls/6',
#     'id': 346734961,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ2NzM0OTYx',
#     'html_url': 'https://github.com/artyom-yurin/CC-Project/pull/6',
#     'diff_url': 'https://github.com/artyom-yurin/CC-Project/pull/6.diff',
#     'patch_url': 'https://github.com/artyom-yurin/CC-Project/pull/6.patch',
#     'issue_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues/6',
#     'number': 6,
#     'state': 'open',
#     'locked': False,
#     'title': 'Ali',
#     'user': {'login': 'Akhmetbekali',
#      'id': 35781410,
#      'node_id': 'MDQ6VXNlcjM1NzgxNDEw',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/35781410?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Akhmetbekali',
#      'html_url': 'https://github.com/Akhmetbekali',
#      'followers_url': 'https://api.github.com/users/Akhmetbekali/followers',
#      'following_url': 'https://api.github.com/users/Akhmetbekali/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Akhmetbekali/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Akhmetbekali/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Akhmetbekali/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Akhmetbekali/orgs',
#      'repos_url': 'https://api.github.com/users/Akhmetbekali/repos',
#      'events_url': 'https://api.github.com/users/Akhmetbekali/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Akhmetbekali/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-11-28T14:47:09Z',
#     'updated_at': '2019-11-28T14:47:09Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls/6/commits',
#     'review_comments_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls/6/comments',
#     'review_comment_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues/6/comments',
#     'statuses_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/statuses/27a8213a4f80ca460e5735b6944e34315725d283',
#     'head': {'label': 'artyom-yurin:Ali',
#      'ref': 'Ali',
#      'sha': '27a8213a4f80ca460e5735b6944e34315725d283',
#      'user': {'login': 'artyom-yurin',
#       'id': 16650505,
#       'node_id': 'MDQ6VXNlcjE2NjUwNTA1',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/16650505?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/artyom-yurin',
#       'html_url': 'https://github.com/artyom-yurin',
#       'followers_url': 'https://api.github.com/users/artyom-yurin/followers',
#       'following_url': 'https://api.github.com/users/artyom-yurin/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/artyom-yurin/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/artyom-yurin/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/artyom-yurin/subscriptions',
#       'organizations_url': 'https://api.github.com/users/artyom-yurin/orgs',
#       'repos_url': 'https://api.github.com/users/artyom-yurin/repos',
#       'events_url': 'https://api.github.com/users/artyom-yurin/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/artyom-yurin/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 218290340,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTgyOTAzNDA=',
#       'name': 'CC-Project',
#       'full_name': 'artyom-yurin/CC-Project',
#       'private': False,
#       'owner': {'login': 'artyom-yurin',
#        'id': 16650505,
#        'node_id': 'MDQ6VXNlcjE2NjUwNTA1',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/16650505?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/artyom-yurin',
#        'html_url': 'https://github.com/artyom-yurin',
#        'followers_url': 'https://api.github.com/users/artyom-yurin/followers',
#        'following_url': 'https://api.github.com/users/artyom-yurin/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/artyom-yurin/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/artyom-yurin/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/artyom-yurin/subscriptions',
#        'organizations_url': 'https://api.github.com/users/artyom-yurin/orgs',
#        'repos_url': 'https://api.github.com/users/artyom-yurin/repos',
#        'events_url': 'https://api.github.com/users/artyom-yurin/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/artyom-yurin/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/artyom-yurin/CC-Project',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/artyom-yurin/CC-Project',
#       'forks_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/forks',
#       'keys_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/teams',
#       'hooks_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/hooks',
#       'issue_events_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/events',
#       'assignees_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/tags',
#       'blobs_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/languages',
#       'stargazers_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/stargazers',
#       'contributors_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/contributors',
#       'subscribers_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/subscribers',
#       'subscription_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/subscription',
#       'commits_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/merges',
#       'archive_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/downloads',
#       'issues_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/deployments',
#       'created_at': '2019-10-29T13:11:51Z',
#       'updated_at': '2019-11-28T13:40:08Z',
#       'pushed_at': '2019-11-28T14:46:10Z',
#       'git_url': 'git://github.com/artyom-yurin/CC-Project.git',
#       'ssh_url': 'git@github.com:artyom-yurin/CC-Project.git',
#       'clone_url': 'https://github.com/artyom-yurin/CC-Project.git',
#       'svn_url': 'https://github.com/artyom-yurin/CC-Project',
#       'homepage': None,
#       'size': 28,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'artyom-yurin:master',
#      'ref': 'master',
#      'sha': '5f336851e7677bb199134c4f849f3b1c0dfa0636',
#      'user': {'login': 'artyom-yurin',
#       'id': 16650505,
#       'node_id': 'MDQ6VXNlcjE2NjUwNTA1',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/16650505?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/artyom-yurin',
#       'html_url': 'https://github.com/artyom-yurin',
#       'followers_url': 'https://api.github.com/users/artyom-yurin/followers',
#       'following_url': 'https://api.github.com/users/artyom-yurin/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/artyom-yurin/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/artyom-yurin/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/artyom-yurin/subscriptions',
#       'organizations_url': 'https://api.github.com/users/artyom-yurin/orgs',
#       'repos_url': 'https://api.github.com/users/artyom-yurin/repos',
#       'events_url': 'https://api.github.com/users/artyom-yurin/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/artyom-yurin/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 218290340,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTgyOTAzNDA=',
#       'name': 'CC-Project',
#       'full_name': 'artyom-yurin/CC-Project',
#       'private': False,
#       'owner': {'login': 'artyom-yurin',
#        'id': 16650505,
#        'node_id': 'MDQ6VXNlcjE2NjUwNTA1',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/16650505?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/artyom-yurin',
#        'html_url': 'https://github.com/artyom-yurin',
#        'followers_url': 'https://api.github.com/users/artyom-yurin/followers',
#        'following_url': 'https://api.github.com/users/artyom-yurin/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/artyom-yurin/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/artyom-yurin/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/artyom-yurin/subscriptions',
#        'organizations_url': 'https://api.github.com/users/artyom-yurin/orgs',
#        'repos_url': 'https://api.github.com/users/artyom-yurin/repos',
#        'events_url': 'https://api.github.com/users/artyom-yurin/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/artyom-yurin/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/artyom-yurin/CC-Project',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/artyom-yurin/CC-Project',
#       'forks_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/forks',
#       'keys_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/teams',
#       'hooks_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/hooks',
#       'issue_events_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/events',
#       'assignees_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/tags',
#       'blobs_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/languages',
#       'stargazers_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/stargazers',
#       'contributors_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/contributors',
#       'subscribers_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/subscribers',
#       'subscription_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/subscription',
#       'commits_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/merges',
#       'archive_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/downloads',
#       'issues_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/artyom-yurin/CC-Project/deployments',
#       'created_at': '2019-10-29T13:11:51Z',
#       'updated_at': '2019-11-28T13:40:08Z',
#       'pushed_at': '2019-11-28T14:46:10Z',
#       'git_url': 'git://github.com/artyom-yurin/CC-Project.git',
#       'ssh_url': 'git@github.com:artyom-yurin/CC-Project.git',
#       'clone_url': 'https://github.com/artyom-yurin/CC-Project.git',
#       'svn_url': 'https://github.com/artyom-yurin/CC-Project',
#       'homepage': None,
#       'size': 28,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls/6'},
#      'html': {'href': 'https://github.com/artyom-yurin/CC-Project/pull/6'},
#      'issue': {'href': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues/6'},
#      'comments': {'href': 'https://api.github.com/repos/artyom-yurin/CC-Project/issues/6/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls/6/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/artyom-yurin/CC-Project/pulls/6/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/artyom-yurin/CC-Project/statuses/27a8213a4f80ca460e5735b6944e34315725d283'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 130,
#     'deletions': 90,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2019-11-28T14:47:10Z'}]

# %%
import json

r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# ade feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1290f1c57001592f12a',
#    'type': 'cat',
#    'text': 'Bobtail cats owe their shortened tails to a natural genetic mutation that has appeared in cats across time and in various regions of the world. The American Bobtail can be traced back to Yodi, a cat with the mutation that was found in Arizona in the 1960s. Yodi passed the genetic quirk on to his kittens, thus creating a new breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
import json

r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Nov 28, 2019 6:40:00 PM',
#    'StationIdentifier': '2560H025',
#    'WaterLevel': 3.14},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1660H013',
#    'WaterLevel': 0.9},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2370H024',
#    'WaterLevel': 195.44},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1650H011',
#    'WaterLevel': 0.4},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1660H011',
#    'WaterLevel': 1.48},
#   {'RecordTime': 'Nov 28, 2019 6:40:00 PM',
#    'StationIdentifier': '2560H023',
#    'WaterLevel': 13.09},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': 0.37},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1730H045',
#    'WaterLevel': 5.13},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1650H006',
#    'WaterLevel': 1.23},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1660H010',
#    'WaterLevel': 7.45},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.36},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1730H077',
#    'WaterLevel': 740.45},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1850H005',
#    'WaterLevel': 22.12},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': 69.12},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1730H036',
#    'WaterLevel': 107.43},
#   {'RecordTime': 'Nov 28, 2019 7:00:00 PM',
#    'StationIdentifier': '1510H063',
#    'WaterLevel': 263.87},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1650H014',
#    'WaterLevel': 1.14},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1510H087',
#    'WaterLevel': 428.66},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1730H072',
#    'WaterLevel': 248.86},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1740H011',
#    'WaterLevel': 6.63},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1430H028',
#    'WaterLevel': 23.56},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2420H018',
#    'WaterLevel': 156.19},
#   {'RecordTime': 'Nov 28, 2019 7:00:00 PM',
#    'StationIdentifier': '1510H050',
#    'WaterLevel': 155.52},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1430H025',
#    'WaterLevel': 9.9},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1730H075',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2200H022',
#    'WaterLevel': 161.4},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1510H081',
#    'WaterLevel': 229.1},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2200H028',
#    'WaterLevel': 278.28},
#   {'RecordTime': 'Nov 28, 2019 7:00:00 PM',
#    'StationIdentifier': '1510H076',
#    'WaterLevel': 4.87},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1730H068',
#    'WaterLevel': 10.14},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1740H002',
#    'WaterLevel': 4.42},
#   {'RecordTime': 'Nov 28, 2019 6:40:00 PM',
#    'StationIdentifier': '2560H020',
#    'WaterLevel': 0.83},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2370H017',
#    'WaterLevel': 58.48},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1300H019',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Nov 28, 2019 6:00:00 PM',
#    'StationIdentifier': '1420H056',
#    'WaterLevel': 196.48},
#   {'RecordTime': 'Nov 28, 2019 7:00:00 PM',
#    'StationIdentifier': '1730H066',
#    'WaterLevel': 138.65},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2200H011',
#    'WaterLevel': 25.58},
#   {'RecordTime': 'Nov 28, 2019 7:00:00 PM',
#    'StationIdentifier': '1510H057',
#    'WaterLevel': 88.46},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2200H021',
#    'WaterLevel': 369.59},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1740H008',
#    'WaterLevel': 1.12},
#   {'RecordTime': 'Nov 28, 2019 7:00:00 PM',
#    'StationIdentifier': '1510H064',
#    'WaterLevel': 265.08},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1550H012',
#    'WaterLevel': 0.17},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.74},
#   {'RecordTime': 'Nov 28, 2019 6:40:00 PM',
#    'StationIdentifier': '2560H017',
#    'WaterLevel': 366.44},
#   {'RecordTime': 'Nov 28, 2019 6:20:00 PM',
#    'StationIdentifier': '1630H033',
#    'WaterLevel': 0.34},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1140H109',
#    'WaterLevel': 48.94},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1270H001',
#    'WaterLevel': 22.47},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1730H061',
#    'WaterLevel': 266.24},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1630H020',
#    'WaterLevel': 35.28},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': 2.99},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1540H032',
#    'WaterLevel': 20.18},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1730H079',
#    'WaterLevel': 548.81},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1730H070',
#    'WaterLevel': 226.2},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1340H013',
#    'WaterLevel': 247.02},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1540H030',
#    'WaterLevel': 27.19},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1510H088',
#    'WaterLevel': 141.08},
#   {'RecordTime': 'Nov 28, 2019 6:40:00 PM',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': 32.08},
#   {'RecordTime': 'Nov 28, 2019 6:20:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.55},
#   {'RecordTime': 'Nov 28, 2019 6:40:00 PM',
#    'StationIdentifier': '2560H006',
#    'WaterLevel': 3.13},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1140H126',
#    'WaterLevel': 81.01},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1430H061',
#    'WaterLevel': 25},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1590H012',
#    'WaterLevel': 2.81},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1630H040',
#    'WaterLevel': 1.77},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 12.78},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1580H020',
#    'WaterLevel': 35.18},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': 26.77},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1340H010',
#    'WaterLevel': 0.62},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1580H013',
#    'WaterLevel': 9.72},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1510H085',
#    'WaterLevel': 279.79},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2420H043',
#    'WaterLevel': 79.42},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.81},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1590H015',
#    'WaterLevel': 9.3},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2420H046',
#    'WaterLevel': 35.99},
#   {'RecordTime': 'Nov 28, 2019 7:00:00 PM',
#    'StationIdentifier': '1140H102',
#    'WaterLevel': 209.5},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1300H024',
#    'WaterLevel': 28.86},
#   {'RecordTime': 'Nov 28, 2019 6:20:00 PM',
#    'StationIdentifier': '1630H034',
#    'WaterLevel': 278.39},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1340H009',
#    'WaterLevel': 175.84},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1550H018',
#    'WaterLevel': -0.03},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1580H007',
#    'WaterLevel': 23.66},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1540H009',
#    'WaterLevel': -0.08},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1540H039',
#    'WaterLevel': 38.98},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1510H084',
#    'WaterLevel': 145.01},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2420H024',
#    'WaterLevel': 4.72},
#   {'RecordTime': 'Nov 28, 2019 6:20:00 PM',
#    'StationIdentifier': '1630H031',
#    'WaterLevel': 0.47},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1340H016',
#    'WaterLevel': -1.11},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1430H037',
#    'WaterLevel': 380.48},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1680H004',
#    'WaterLevel': 1.11},
#   {'RecordTime': 'Nov 28, 2019 7:10:00 PM',
#    'StationIdentifier': '1140H095',
#    'WaterLevel': 110.03},
#   {'RecordTime': 'Nov 28, 2019 7:10:00 PM',
#    'StationIdentifier': '1140H049',
#    'WaterLevel': 22.11},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1430H056',
#    'WaterLevel': 79.83},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1310H002',
#    'WaterLevel': 0.99},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1430H030',
#    'WaterLevel': 87.49},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1420H052',
#    'WaterLevel': 428.99},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1350H022',
#    'WaterLevel': 253.89},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1540H037',
#    'WaterLevel': 32.08},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '2370H019',
#    'WaterLevel': 156.02},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1430H058',
#    'WaterLevel': 83.15},
#   {'RecordTime': 'Nov 28, 2019 6:20:00 PM',
#    'StationIdentifier': '1630H027',
#    'WaterLevel': 26.16},
#   {'RecordTime': 'Nov 28, 2019 6:50:00 PM',
#    'StationIdentifier': '1320H002',
#    'WaterLevel': 17.97},
#   {'RecordTime': 'Nov 28, 2019 6:55:00 PM',
#    'StationIdentifier': '1140H107',
#    'WaterLevel': 2.57}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
